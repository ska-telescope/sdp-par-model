# %% [markdown]
# # Scheduling Model inputs for SV AA2 Low
#
# Batch-generate scheduling and processing block data for use in scheduling experiments

# %%
import json
import sys
import yaml
import math
import tempfile
 
sys.path.insert(0, "..")
from sdp_par_model.config import PipelineConfig
from sdp_par_model.parameters.definitions import Constants

# %% [markdown]
# ## Specify output filenames

# %%
pipeline_config_output_path = "../data/output/sv_aa2_low_pipelines_v1.json"
scheduling_block_types_config_output_path = "../data/output/sv_aa2_low_scheduling_block_types_v1.json"

# %% [markdown]
# ## Load parameters
#
# Expected to be a list of parametric model configuration dictionaries.
#
# Can be generated from Google Sheets (Sheets to JSON -> Array of rows -> Download/Generate)

# %%
with open("../data/configs/stage_1/svaa2_low_v1.json") as stream:
    yamls = yaml.safe_load(stream)
print(f"Loaded {len(yamls)} pipeline configurations: {', '.join(yaml['name'] for yaml in yamls)}")
# Out:
# Loaded 49 pipeline configurations: DSC-015-1 ICAL, DSC-015-1 CIMG, DSC-020 ICAL, DSC-020 CIMG 1, DSC-020 CIMG 2, DSC-020 CIMG 3, DSC-020 SIMG 1, DSC-020 SIMG 2, DSC-020 SIMG 3, DSC-023 ICAL, DSC-023 CIMG, DSC-023 SIMG, SC-025 ICAL, SC-025 CIMG 1, SC-025 CIMG 2, SC-026 ICAL, SC-026 CIMG , SC-027 ICAL, SC-027 CIMG , SC-028 ICAL, SC-028 CIMG , SC-028 SIMG , SC-028-1 ICAL, SC-028-1 CIMG 1, SC-028-1 CIMG 2, SC-028-1 SIMG 1, SC-028-1 SIMG 2, SC-029 ICAL, SC-029 CIMG , SC-029 SIMG , SC-029-1 ICAL, SC-029-1 CIMG  , SC-029-1 SIMG  , SC-030 ICAL, SC-030 CIMG, SC-030 SIMG, SC-031 ICAL, SC-031 CIMG , SC-032 ICAL, SC-032 CIMG, SC-032 SIMG, SC-033 ICAL, SC-033 CIMG , Stretch-003 ICAL, Stretch-003 CIMG , Stretch-003 SIMG , Stretch-004 ICAL, Stretch-004 CIMG , Stretch-004 SIMG

# %% [markdown]
# ## Base assumptions
#
# We will likely need to revise this quite a bit to calibrate the appropriate level of "optimism". For the moment, let's keep with conservative estimates.

# %%
# Base assumptions
data_retention_hrs = 24.0
node_hours_uncertainty = 0.1
pct_parallelism = {
    "ICAL": 50.0,
    "DPrepA": 50.0,
    "DPrepB": 90.0,
}
pct_parallelism_max = {
    "ICAL": 75.0,
    "DPrepA": 75.0,
    "DPrepB": 95.0,
}
num_nodes = {
    "ICAL": 25,
    "DPrepA": 25,
    "DPrepB": 50,
}
    
# Extrapolation data
benchmark_node_hours = 30+8/60+26/60/60 # Strictly speaking using 3 nodes
Rflop_reference = 4324483174870.51
Tobs_ref = 8 * 3600

# %% [markdown]
# ## Generate configurations

# %%
pipelines = {}
scheduling_block_types = {}

for to_calculate in yamls:

    # Get name. Assume that everything up to first blank is the scheduling block definition name
    pip_name = to_calculate['name']
    sbd_name = pip_name.split(' ')[0]

    # Calculate parameters
    print('\n===',pip_name,'===')
    with tempfile.NamedTemporaryFile('w') as f:
        yaml.dump(to_calculate, f)
        pars = PipelineConfig(use_yaml=True, yaml_path=f.name).calc_tel_params(verbose=True)

    # Print
    node_hours = benchmark_node_hours * float(pars.Rflop * pars.Tobs) / (Rflop_reference * Tobs_ref)
    vis_size_gb = int(math.ceil(pars.Rvis_ingest*pars.Tobs/1e9))
    averaged_vis_size_gb = int(math.ceil(pars.Rvis(pars.Bmax, bcount=pars.Nbl_full)*pars.Tobs/1e9))
    output_size_gb = int(math.ceil(pars.Mout/1e9))
    print(f"Compute time:             {node_hours:.7} Nh")
    print(f"Ingest visibility size:   {vis_size_gb} GB")
    print(f"Averaged visibility size: {averaged_vis_size_gb} GB")
    print(f"Output size:              {output_size_gb} GB")
    print(f"Fiducial frequency:       {pars.c / pars.wl_sb_min / Constants.mega} MHz")
    #print(3 * (pars.c / 135e6) / 2 / 39e3 / 3 / Constants.arcsecond)
    print(f"Beam size:                {pars.Theta_beam / Constants.arcsecond}\"")
    print(f"Pixel size:               {pars.Theta_pix / Constants.arcsecond}\"")

    # Generate data
    if sbd_name not in scheduling_block_types:
        scheduling_block_types[sbd_name] = {
            "description": sbd_name,
            "short_name": sbd_name,
            "sampling_weight": pars.Tpoint / 3600,
            "scheduling_block_instance_time_hrs": pars.Tobs / 3600,
            "integration_time_hrs": max(pars.Tobs, pars.Tpoint) / 3600,
            "pipeline_steps": [],
            "raw_vis_gb": vis_size_gb,
            "processed_vis_gb": averaged_vis_size_gb,
            "data_retention_hrs": data_retention_hrs
        }

    # Add pipeline
    assert pip_name not in pipelines, f"Duplicated pipeline name {pip_name}!"
    scheduling_block_types[sbd_name]['pipeline_steps'].append(pip_name)
    pipelines[pip_name] = {
        "description": pip_name,
        "node_hours": node_hours,
        "node_hours_uncertainty": node_hours_uncertainty,
        "pct_parallelism": pct_parallelism[pars.pipeline],
        "pct_parallelism_max": pct_parallelism_max[pars.pipeline],
        "data_product_storage_gb": output_size_gb,
        "num_nodes": num_nodes[pars.pipeline]
    }
# Out:
# === DSC-015-1 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=20.8109, Rflop=6.33891e+13
# Evaluating Nfacet=2 -> DeltaW_stack=27.0809, Rflop=7.08659e+13
# Evaluating Nfacet=3 -> DeltaW_stack=34.1028, Rflop=6.17989e+13
# Evaluating Nfacet=4 -> DeltaW_stack=39.5711, Rflop=6.16194e+13
# Evaluating Nfacet=5 -> DeltaW_stack=46.6814, Rflop=6.05364e+13
# Evaluating Nfacet=6 -> DeltaW_stack=51.2456, Rflop=6.6001e+13
# Evaluating Nfacet=7 -> DeltaW_stack=57.0999, Rflop=6.98287e+13
# Nfacet=5, DeltaW_stack=46.6814  yielded the lowest value of Rflop=6.05364e+13
# Compute time:             210.9616 Nh
# Ingest visibility size:   337 GB
# Averaged visibility size: 54 GB
# Output size:              0 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === DSC-015-1 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.79775, Rflop=3.90199e+13
# Evaluating Nfacet=2 -> DeltaW_stack=12.3375, Rflop=5.17836e+13
# Evaluating Nfacet=3 -> DeltaW_stack=15.0271, Rflop=5.80393e+13
# Nfacet=1, DeltaW_stack=9.79775  yielded the lowest value of Rflop=3.90199e+13
# Compute time:             135.9794 Nh
# Ingest visibility size:   337 GB
# Averaged visibility size: 54 GB
# Output size:              64 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === DSC-020 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=20.8109, Rflop=6.33891e+13
# Evaluating Nfacet=2 -> DeltaW_stack=27.0809, Rflop=7.08659e+13
# Evaluating Nfacet=3 -> DeltaW_stack=34.1028, Rflop=6.17989e+13
# Evaluating Nfacet=4 -> DeltaW_stack=39.5711, Rflop=6.16194e+13
# Evaluating Nfacet=5 -> DeltaW_stack=46.6814, Rflop=6.05364e+13
# Evaluating Nfacet=6 -> DeltaW_stack=51.2456, Rflop=6.6001e+13
# Evaluating Nfacet=7 -> DeltaW_stack=57.0999, Rflop=6.98287e+13
# Nfacet=5, DeltaW_stack=46.6814  yielded the lowest value of Rflop=6.05364e+13
# Compute time:             210.9616 Nh
# Ingest visibility size:   337 GB
# Averaged visibility size: 54 GB
# Output size:              0 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === DSC-020 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.79775, Rflop=3.90199e+13
# Evaluating Nfacet=2 -> DeltaW_stack=12.3375, Rflop=5.17836e+13
# Evaluating Nfacet=3 -> DeltaW_stack=15.0271, Rflop=5.80393e+13
# Nfacet=1, DeltaW_stack=9.79775  yielded the lowest value of Rflop=3.90199e+13
# Compute time:             135.9794 Nh
# Ingest visibility size:   337 GB
# Averaged visibility size: 54 GB
# Output size:              64 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === DSC-020 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=5.32893, Rflop=4.65331e+12
# Evaluating Nfacet=2 -> DeltaW_stack=6.57091, Rflop=7.44623e+12
# Evaluating Nfacet=3 -> DeltaW_stack=7.68718, Rflop=1.08424e+13
# Nfacet=1, DeltaW_stack=5.32893  yielded the lowest value of Rflop=4.65331e+12
# Compute time:             16.21618 Nh
# Ingest visibility size:   128 GB
# Averaged visibility size: 14 GB
# Output size:              8 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                18.5062964640876"
# Pixel size:               9.25314823204382"
#
# === DSC-020 CIMG 3 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.05057, Rflop=8.78231e+11
# Evaluating Nfacet=2 -> DeltaW_stack=4.93336, Rflop=1.53936e+12
# Evaluating Nfacet=3 -> DeltaW_stack=5.72131, Rflop=2.4518e+12
# Nfacet=1, DeltaW_stack=4.05057  yielded the lowest value of Rflop=8.78231e+11
# Compute time:             3.060522 Nh
# Ingest visibility size:   41 GB
# Averaged visibility size: 4 GB
# Output size:              2 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                37.0125929281753"
# Pixel size:               18.5062964640876"
#
# === DSC-020 SIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=10.8471, Rflop=2.79069e+13
# Evaluating Nfacet=2 -> DeltaW_stack=14.0439, Rflop=3.40146e+13
# Evaluating Nfacet=3 -> DeltaW_stack=17.4532, Rflop=3.48103e+13
# Nfacet=1, DeltaW_stack=10.8471  yielded the lowest value of Rflop=2.79069e+13
# Compute time:             97.25193 Nh
# Ingest visibility size:   337 GB
# Averaged visibility size: 54 GB
# Output size:              80 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === DSC-020 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=5.89899, Rflop=3.50734e+12
# Evaluating Nfacet=2 -> DeltaW_stack=7.38944, Rflop=5.07947e+12
# Evaluating Nfacet=3 -> DeltaW_stack=8.70945, Rflop=6.8513e+12
# Nfacet=1, DeltaW_stack=5.89899  yielded the lowest value of Rflop=3.50734e+12
# Compute time:             12.22263 Nh
# Ingest visibility size:   128 GB
# Averaged visibility size: 14 GB
# Output size:              9 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                18.5062964640876"
# Pixel size:               9.25314823204382"
#
# === DSC-020 SIMG 3 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.48679, Rflop=7.60563e+11
# Evaluating Nfacet=2 -> DeltaW_stack=5.52859, Rflop=1.19599e+12
# Evaluating Nfacet=3 -> DeltaW_stack=6.4416, Rflop=1.79036e+12
# Nfacet=1, DeltaW_stack=4.48679  yielded the lowest value of Rflop=7.60563e+11
# Compute time:             2.650465 Nh
# Ingest visibility size:   41 GB
# Averaged visibility size: 4 GB
# Output size:              3 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                37.0125929281753"
# Pixel size:               18.5062964640876"
#
# === DSC-023 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=20.8109, Rflop=6.33891e+13
# Evaluating Nfacet=2 -> DeltaW_stack=27.0809, Rflop=7.08659e+13
# Evaluating Nfacet=3 -> DeltaW_stack=34.1028, Rflop=6.17989e+13
# Evaluating Nfacet=4 -> DeltaW_stack=39.5711, Rflop=6.16194e+13
# Evaluating Nfacet=5 -> DeltaW_stack=46.6814, Rflop=6.05364e+13
# Evaluating Nfacet=6 -> DeltaW_stack=51.2456, Rflop=6.6001e+13
# Evaluating Nfacet=7 -> DeltaW_stack=57.0999, Rflop=6.98287e+13
# Nfacet=5, DeltaW_stack=46.6814  yielded the lowest value of Rflop=6.05364e+13
# Compute time:             210.9616 Nh
# Ingest visibility size:   337 GB
# Averaged visibility size: 54 GB
# Output size:              0 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === DSC-023 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=14.6497, Rflop=2.05752e+13
# Evaluating Nfacet=2 -> DeltaW_stack=18.5148, Rflop=2.54791e+13
# Evaluating Nfacet=3 -> DeltaW_stack=22.6609, Rflop=2.57659e+13
# Nfacet=1, DeltaW_stack=14.6497  yielded the lowest value of Rflop=2.05752e+13
# Compute time:             71.70212 Nh
# Ingest visibility size:   324 GB
# Averaged visibility size: 18 GB
# Output size:              28 GB
# Fiducial frequency:       129.889460842382 MHz
# Beam size:                9.65009216860195"
# Pixel size:               3.21669738953398"
#
# === DSC-023 SIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=8.91123, Rflop=6.33116e+12
# Evaluating Nfacet=2 -> DeltaW_stack=11.4495, Rflop=8.17385e+12
# Evaluating Nfacet=3 -> DeltaW_stack=14.1086, Rflop=9.12087e+12
# Nfacet=1, DeltaW_stack=8.91123  yielded the lowest value of Rflop=6.33116e+12
# Compute time:             22.06331 Nh
# Ingest visibility size:   324 GB
# Averaged visibility size: 18 GB
# Output size:              14 GB
# Fiducial frequency:       129.889460842382 MHz
# Beam size:                9.65009216860195"
# Pixel size:               3.21669738953398"
#
# === SC-025 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=91.1881, Rflop=3.26367e+13
# Evaluating Nfacet=2 -> DeltaW_stack=118.697, Rflop=3.67029e+13
# Evaluating Nfacet=3 -> DeltaW_stack=149.492, Rflop=3.22589e+13
# Evaluating Nfacet=4 -> DeltaW_stack=173.397, Rflop=3.23727e+13
# Evaluating Nfacet=5 -> DeltaW_stack=204.602, Rflop=3.19672e+13
# Evaluating Nfacet=6 -> DeltaW_stack=224.518, Rflop=3.49833e+13
# Evaluating Nfacet=7 -> DeltaW_stack=250.045, Rflop=3.71267e+13
# Nfacet=5, DeltaW_stack=204.602  yielded the lowest value of Rflop=3.19672e+13
# Compute time:             111.4016 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              0 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-025 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=42.8144, Rflop=2.00973e+13
# Evaluating Nfacet=2 -> DeltaW_stack=53.8904, Rflop=2.6911e+13
# Evaluating Nfacet=3 -> DeltaW_stack=65.6079, Rflop=3.04919e+13
# Nfacet=1, DeltaW_stack=42.8144  yielded the lowest value of Rflop=2.00973e+13
# Compute time:             70.03667 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              33 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-025 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=23.26, Rflop=2.42386e+12
# Evaluating Nfacet=2 -> DeltaW_stack=28.6669, Rflop=3.92077e+12
# Evaluating Nfacet=3 -> DeltaW_stack=33.5281, Rflop=5.76387e+12
# Nfacet=1, DeltaW_stack=23.26  yielded the lowest value of Rflop=2.42386e+12
# Compute time:             8.446854 Nh
# Ingest visibility size:   129 GB
# Averaged visibility size: 8 GB
# Output size:              4 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                8.56269574621544"
# Pixel size:               4.28134787310772"
#
# === SC-026 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=91.1881, Rflop=3.26367e+13
# Evaluating Nfacet=2 -> DeltaW_stack=118.697, Rflop=3.67029e+13
# Evaluating Nfacet=3 -> DeltaW_stack=149.492, Rflop=3.22589e+13
# Evaluating Nfacet=4 -> DeltaW_stack=173.397, Rflop=3.23727e+13
# Evaluating Nfacet=5 -> DeltaW_stack=204.602, Rflop=3.19672e+13
# Evaluating Nfacet=6 -> DeltaW_stack=224.518, Rflop=3.49833e+13
# Evaluating Nfacet=7 -> DeltaW_stack=250.045, Rflop=3.71267e+13
# Nfacet=5, DeltaW_stack=204.602  yielded the lowest value of Rflop=3.19672e+13
# Compute time:             111.4016 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              0 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-026 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=42.8144, Rflop=2.00973e+13
# Evaluating Nfacet=2 -> DeltaW_stack=53.8904, Rflop=2.6911e+13
# Evaluating Nfacet=3 -> DeltaW_stack=65.6079, Rflop=3.04919e+13
# Nfacet=1, DeltaW_stack=42.8144  yielded the lowest value of Rflop=2.00973e+13
# Compute time:             70.03667 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              33 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-027 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.85673, Rflop=9.17897e+13
# Evaluating Nfacet=2 -> DeltaW_stack=12.8294, Rflop=1.01981e+14
# Evaluating Nfacet=3 -> DeltaW_stack=16.1715, Rflop=8.7921e+13
# Evaluating Nfacet=4 -> DeltaW_stack=18.7527, Rflop=8.66205e+13
# Evaluating Nfacet=5 -> DeltaW_stack=22.1357, Rflop=8.42264e+13
# Evaluating Nfacet=6 -> DeltaW_stack=24.3714, Rflop=9.0952e+13
# Evaluating Nfacet=7 -> DeltaW_stack=27.1671, Rflop=9.55184e+13
# Nfacet=5, DeltaW_stack=22.1357  yielded the lowest value of Rflop=8.42264e+13
# Compute time:             293.5183 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              0 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-027 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.64895, Rflop=5.60171e+13
# Evaluating Nfacet=2 -> DeltaW_stack=5.86068, Rflop=7.33027e+13
# Evaluating Nfacet=3 -> DeltaW_stack=7.14628, Rflop=8.06159e+13
# Nfacet=1, DeltaW_stack=4.64895  yielded the lowest value of Rflop=5.60171e+13
# Compute time:             195.2124 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              82 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-028 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.85673, Rflop=9.17897e+13
# Evaluating Nfacet=2 -> DeltaW_stack=12.8294, Rflop=1.01981e+14
# Evaluating Nfacet=3 -> DeltaW_stack=16.1715, Rflop=8.7921e+13
# Evaluating Nfacet=4 -> DeltaW_stack=18.7527, Rflop=8.66205e+13
# Evaluating Nfacet=5 -> DeltaW_stack=22.1357, Rflop=8.42264e+13
# Evaluating Nfacet=6 -> DeltaW_stack=24.3714, Rflop=9.0952e+13
# Evaluating Nfacet=7 -> DeltaW_stack=27.1671, Rflop=9.55184e+13
# Nfacet=5, DeltaW_stack=22.1357  yielded the lowest value of Rflop=8.42264e+13
# Compute time:             293.5183 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              0 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-028 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.64895, Rflop=5.60171e+13
# Evaluating Nfacet=2 -> DeltaW_stack=5.86068, Rflop=7.33027e+13
# Evaluating Nfacet=3 -> DeltaW_stack=7.14628, Rflop=8.06159e+13
# Nfacet=1, DeltaW_stack=4.64895  yielded the lowest value of Rflop=5.60171e+13
# Compute time:             195.2124 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              1 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-028 SIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.26702, Rflop=3.06596e+13
# Evaluating Nfacet=2 -> DeltaW_stack=5.51208, Rflop=3.82785e+13
# Evaluating Nfacet=3 -> DeltaW_stack=6.82817, Rflop=4.07063e+13
# Nfacet=1, DeltaW_stack=4.26702  yielded the lowest value of Rflop=3.06596e+13
# Compute time:             106.8447 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              1 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-028-1 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=91.1881, Rflop=3.26367e+13
# Evaluating Nfacet=2 -> DeltaW_stack=118.697, Rflop=3.67029e+13
# Evaluating Nfacet=3 -> DeltaW_stack=149.492, Rflop=3.22589e+13
# Evaluating Nfacet=4 -> DeltaW_stack=173.397, Rflop=3.23727e+13
# Evaluating Nfacet=5 -> DeltaW_stack=204.602, Rflop=3.19672e+13
# Evaluating Nfacet=6 -> DeltaW_stack=224.518, Rflop=3.49833e+13
# Evaluating Nfacet=7 -> DeltaW_stack=250.045, Rflop=3.71267e+13
# Nfacet=5, DeltaW_stack=204.602  yielded the lowest value of Rflop=3.19672e+13
# Compute time:             111.4016 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              0 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-028-1 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=42.8144, Rflop=2.00973e+13
# Evaluating Nfacet=2 -> DeltaW_stack=53.8904, Rflop=2.6911e+13
# Evaluating Nfacet=3 -> DeltaW_stack=65.6079, Rflop=3.04919e+13
# Nfacet=1, DeltaW_stack=42.8144  yielded the lowest value of Rflop=2.00973e+13
# Compute time:             70.03667 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              1 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-028-1 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=23.26, Rflop=2.42386e+12
# Evaluating Nfacet=2 -> DeltaW_stack=28.6669, Rflop=3.92077e+12
# Evaluating Nfacet=3 -> DeltaW_stack=33.5281, Rflop=5.76387e+12
# Nfacet=1, DeltaW_stack=23.26  yielded the lowest value of Rflop=2.42386e+12
# Compute time:             8.446854 Nh
# Ingest visibility size:   129 GB
# Averaged visibility size: 8 GB
# Output size:              1 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                8.56269574621544"
# Pixel size:               4.28134787310772"
#
# === SC-028-1 SIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=39.417, Rflop=1.11046e+13
# Evaluating Nfacet=2 -> DeltaW_stack=50.8158, Rflop=1.4154e+13
# Evaluating Nfacet=3 -> DeltaW_stack=62.7999, Rflop=1.55158e+13
# Nfacet=1, DeltaW_stack=39.417  yielded the lowest value of Rflop=1.11046e+13
# Compute time:             38.69829 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              1 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-028-1 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=21.247, Rflop=1.53673e+12
# Evaluating Nfacet=2 -> DeltaW_stack=26.4637, Rflop=2.35479e+12
# Evaluating Nfacet=3 -> DeltaW_stack=31.0786, Rflop=3.38836e+12
# Nfacet=1, DeltaW_stack=21.247  yielded the lowest value of Rflop=1.53673e+12
# Compute time:             5.355313 Nh
# Ingest visibility size:   129 GB
# Averaged visibility size: 8 GB
# Output size:              1 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                8.56269574621544"
# Pixel size:               4.28134787310772"
#
# === SC-029 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.85673, Rflop=9.17897e+13
# Evaluating Nfacet=2 -> DeltaW_stack=12.8294, Rflop=1.01981e+14
# Evaluating Nfacet=3 -> DeltaW_stack=16.1715, Rflop=8.7921e+13
# Evaluating Nfacet=4 -> DeltaW_stack=18.7527, Rflop=8.66205e+13
# Evaluating Nfacet=5 -> DeltaW_stack=22.1357, Rflop=8.42264e+13
# Evaluating Nfacet=6 -> DeltaW_stack=24.3714, Rflop=9.0952e+13
# Evaluating Nfacet=7 -> DeltaW_stack=27.1671, Rflop=9.55184e+13
# Nfacet=5, DeltaW_stack=22.1357  yielded the lowest value of Rflop=8.42264e+13
# Compute time:             293.5183 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              0 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-029 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.64895, Rflop=5.60171e+13
# Evaluating Nfacet=2 -> DeltaW_stack=5.86068, Rflop=7.33027e+13
# Evaluating Nfacet=3 -> DeltaW_stack=7.14628, Rflop=8.06159e+13
# Nfacet=1, DeltaW_stack=4.64895  yielded the lowest value of Rflop=5.60171e+13
# Compute time:             195.2124 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              82 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-029 SIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.26702, Rflop=3.06596e+13
# Evaluating Nfacet=2 -> DeltaW_stack=5.51208, Rflop=3.82785e+13
# Evaluating Nfacet=3 -> DeltaW_stack=6.82817, Rflop=4.07063e+13
# Nfacet=1, DeltaW_stack=4.26702  yielded the lowest value of Rflop=3.06596e+13
# Compute time:             106.8447 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              49 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-029-1 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=91.1881, Rflop=3.26367e+13
# Evaluating Nfacet=2 -> DeltaW_stack=118.697, Rflop=3.67029e+13
# Evaluating Nfacet=3 -> DeltaW_stack=149.492, Rflop=3.22589e+13
# Evaluating Nfacet=4 -> DeltaW_stack=173.397, Rflop=3.23727e+13
# Evaluating Nfacet=5 -> DeltaW_stack=204.602, Rflop=3.19672e+13
# Evaluating Nfacet=6 -> DeltaW_stack=224.518, Rflop=3.49833e+13
# Evaluating Nfacet=7 -> DeltaW_stack=250.045, Rflop=3.71267e+13
# Nfacet=5, DeltaW_stack=204.602  yielded the lowest value of Rflop=3.19672e+13
# Compute time:             111.4016 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              0 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-029-1 CIMG   ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=42.8144, Rflop=2.00973e+13
# Evaluating Nfacet=2 -> DeltaW_stack=53.8904, Rflop=2.6911e+13
# Evaluating Nfacet=3 -> DeltaW_stack=65.6079, Rflop=3.04919e+13
# Nfacet=1, DeltaW_stack=42.8144  yielded the lowest value of Rflop=2.00973e+13
# Compute time:             70.03667 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              33 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-029-1 SIMG   ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=61.0699, Rflop=2.11329e+13
# Evaluating Nfacet=2 -> DeltaW_stack=79.4623, Rflop=2.49415e+13
# Evaluating Nfacet=3 -> DeltaW_stack=99.3406, Rflop=2.415e+13
# Evaluating Nfacet=4 -> DeltaW_stack=114.125, Rflop=2.68062e+13
# Evaluating Nfacet=5 -> DeltaW_stack=133.916, Rflop=2.8643e+13
# Nfacet=1, DeltaW_stack=61.0699  yielded the lowest value of Rflop=2.11329e+13
# Compute time:             73.64564 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              165 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === SC-030 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=15.8313, Rflop=1.11542e+13
# Evaluating Nfacet=2 -> DeltaW_stack=20.2121, Rflop=1.35117e+13
# Evaluating Nfacet=3 -> DeltaW_stack=24.3189, Rflop=1.4121e+13
# Nfacet=1, DeltaW_stack=15.8313  yielded the lowest value of Rflop=1.11542e+13
# Compute time:             9.717756 Nh
# Ingest visibility size:   32 GB
# Averaged visibility size: 4 GB
# Output size:              0 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                18.5062964640876"
# Pixel size:               6.16876548802921"
#
# === SC-030 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=7.39675, Rflop=6.81937e+12
# Evaluating Nfacet=2 -> DeltaW_stack=9.18084, Rflop=9.88618e+12
# Evaluating Nfacet=3 -> DeltaW_stack=10.79, Rflop=1.29416e+13
# Nfacet=1, DeltaW_stack=7.39675  yielded the lowest value of Rflop=6.81937e+12
# Compute time:             5.941165 Nh
# Ingest visibility size:   32 GB
# Averaged visibility size: 4 GB
# Output size:              1 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                18.5062964640876"
# Pixel size:               6.16876548802921"
#
# === SC-030 SIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=8.42721, Rflop=1.98194e+13
# Evaluating Nfacet=2 -> DeltaW_stack=10.8513, Rflop=2.54793e+13
# Evaluating Nfacet=3 -> DeltaW_stack=13.3948, Rflop=2.83514e+13
# Nfacet=1, DeltaW_stack=8.42721  yielded the lowest value of Rflop=1.98194e+13
# Compute time:             17.26706 Nh
# Ingest visibility size:   85 GB
# Averaged visibility size: 14 GB
# Output size:              2 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === SC-031 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.85673, Rflop=9.17897e+13
# Evaluating Nfacet=2 -> DeltaW_stack=12.8294, Rflop=1.01981e+14
# Evaluating Nfacet=3 -> DeltaW_stack=16.1715, Rflop=8.7921e+13
# Evaluating Nfacet=4 -> DeltaW_stack=18.7527, Rflop=8.66205e+13
# Evaluating Nfacet=5 -> DeltaW_stack=22.1357, Rflop=8.42264e+13
# Evaluating Nfacet=6 -> DeltaW_stack=24.3714, Rflop=9.0952e+13
# Evaluating Nfacet=7 -> DeltaW_stack=27.1671, Rflop=9.55184e+13
# Nfacet=5, DeltaW_stack=22.1357  yielded the lowest value of Rflop=8.42264e+13
# Compute time:             293.5183 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              0 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-031 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=4.64895, Rflop=5.60171e+13
# Evaluating Nfacet=2 -> DeltaW_stack=5.86068, Rflop=7.33027e+13
# Evaluating Nfacet=3 -> DeltaW_stack=7.14628, Rflop=8.06159e+13
# Nfacet=1, DeltaW_stack=4.64895  yielded the lowest value of Rflop=5.60171e+13
# Compute time:             195.2124 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 71 GB
# Output size:              82 GB
# Fiducial frequency:       91.8958683997628 MHz
# Beam size:                13.6398435608258"
# Pixel size:               4.54661452027528"
#
# === SC-032 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=20.8109, Rflop=6.40193e+13
# Evaluating Nfacet=2 -> DeltaW_stack=27.0809, Rflop=7.18742e+13
# Evaluating Nfacet=3 -> DeltaW_stack=34.1028, Rflop=6.34367e+13
# Evaluating Nfacet=4 -> DeltaW_stack=39.5711, Rflop=6.41384e+13
# Evaluating Nfacet=5 -> DeltaW_stack=46.6814, Rflop=6.41884e+13
# Nfacet=3, DeltaW_stack=34.1028  yielded the lowest value of Rflop=6.34367e+13
# Compute time:             55.2672 Nh
# Ingest visibility size:   85 GB
# Averaged visibility size: 14 GB
# Output size:              0 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === SC-032 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.79775, Rflop=3.90978e+13
# Evaluating Nfacet=2 -> DeltaW_stack=12.3375, Rflop=5.19082e+13
# Evaluating Nfacet=3 -> DeltaW_stack=15.0271, Rflop=5.82408e+13
# Nfacet=1, DeltaW_stack=9.79775  yielded the lowest value of Rflop=3.90978e+13
# Compute time:             34.06277 Nh
# Ingest visibility size:   85 GB
# Averaged visibility size: 14 GB
# Output size:              2 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === SC-032 SIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=13.9554, Rflop=4.16249e+13
# Evaluating Nfacet=2 -> DeltaW_stack=18.1301, Rflop=4.90507e+13
# Evaluating Nfacet=3 -> DeltaW_stack=22.6701, Rflop=4.76624e+13
# Evaluating Nfacet=4 -> DeltaW_stack=26.0535, Rflop=5.31498e+13
# Evaluating Nfacet=5 -> DeltaW_stack=30.5626, Rflop=5.73619e+13
# Nfacet=1, DeltaW_stack=13.9554  yielded the lowest value of Rflop=4.16249e+13
# Compute time:             36.26438 Nh
# Ingest visibility size:   85 GB
# Averaged visibility size: 14 GB
# Output size:              5 GB
# Fiducial frequency:       135.461492394372 MHz
# Beam size:                9.25314823204382"
# Pixel size:               3.08438274401461"
#
# === SC-033 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=50.385, Rflop=3.4505e+12
# Evaluating Nfacet=2 -> DeltaW_stack=63.9966, Rflop=4.34403e+12
# Evaluating Nfacet=3 -> DeltaW_stack=76.8898, Rflop=4.79669e+12
# Nfacet=1, DeltaW_stack=50.385  yielded the lowest value of Rflop=3.4505e+12
# Compute time:             12.02456 Nh
# Ingest visibility size:   129 GB
# Averaged visibility size: 8 GB
# Output size:              0 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                8.56269574621544"
# Pixel size:               4.28134787310772"
#
# === SC-033 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=23.26, Rflop=2.42386e+12
# Evaluating Nfacet=2 -> DeltaW_stack=28.6669, Rflop=3.92077e+12
# Evaluating Nfacet=3 -> DeltaW_stack=33.5281, Rflop=5.76387e+12
# Nfacet=1, DeltaW_stack=23.26  yielded the lowest value of Rflop=2.42386e+12
# Compute time:             8.446854 Nh
# Ingest visibility size:   129 GB
# Averaged visibility size: 8 GB
# Output size:              4 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                8.56269574621544"
# Pixel size:               4.28134787310772"
#
# === Stretch-003 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=91.1881, Rflop=3.26367e+13
# Evaluating Nfacet=2 -> DeltaW_stack=118.697, Rflop=3.67029e+13
# Evaluating Nfacet=3 -> DeltaW_stack=149.492, Rflop=3.22589e+13
# Evaluating Nfacet=4 -> DeltaW_stack=173.397, Rflop=3.23727e+13
# Evaluating Nfacet=5 -> DeltaW_stack=204.602, Rflop=3.19672e+13
# Evaluating Nfacet=6 -> DeltaW_stack=224.518, Rflop=3.49833e+13
# Evaluating Nfacet=7 -> DeltaW_stack=250.045, Rflop=3.71267e+13
# Nfacet=5, DeltaW_stack=204.602  yielded the lowest value of Rflop=3.19672e+13
# Compute time:             111.4016 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              0 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === Stretch-003 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=42.8144, Rflop=2.00973e+13
# Evaluating Nfacet=2 -> DeltaW_stack=53.8904, Rflop=2.6911e+13
# Evaluating Nfacet=3 -> DeltaW_stack=65.6079, Rflop=3.04919e+13
# Nfacet=1, DeltaW_stack=42.8144  yielded the lowest value of Rflop=2.00973e+13
# Compute time:             70.03667 Nh
# Ingest visibility size:   340 GB
# Averaged visibility size: 29 GB
# Output size:              33 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                4.28134787310772"
# Pixel size:               1.42711595770257"
#
# === Stretch-003 SIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=315.343, Rflop=1.66103e+14
# Evaluating Nfacet=2 -> DeltaW_stack=395.628, Rflop=1.94555e+14
# Evaluating Nfacet=3 -> DeltaW_stack=472.216, Rflop=1.94271e+14
# Evaluating Nfacet=4 -> DeltaW_stack=700.459, Rflop=2.20388e+14
# Evaluating Nfacet=5 -> DeltaW_stack=769.81, Rflop=2.56705e+14
# Nfacet=1, DeltaW_stack=315.343  yielded the lowest value of Rflop=1.66103e+14
# Compute time:             578.8496 Nh
# Ingest visibility size:   298 GB
# Averaged visibility size: 40 GB
# Output size:              9650 GB
# Fiducial frequency:       253.609462524784 MHz
# Beam size:                4.94242311142672"
# Pixel size:               1.64747437047557"
#
# === Stretch-004 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=71.486, Rflop=6.1912e+12
# Evaluating Nfacet=2 -> DeltaW_stack=91.4658, Rflop=7.39496e+12
# Evaluating Nfacet=3 -> DeltaW_stack=110.154, Rflop=7.36415e+12
# Evaluating Nfacet=4 -> DeltaW_stack=124.307, Rflop=8.28379e+12
# Evaluating Nfacet=5 -> DeltaW_stack=143.499, Rflop=9.02563e+12
# Nfacet=1, DeltaW_stack=71.486  yielded the lowest value of Rflop=6.1912e+12
# Compute time:             21.57557 Nh
# Ingest visibility size:   138 GB
# Averaged visibility size: 8 GB
# Output size:              0 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                8.12358314384542"
# Pixel size:               2.70786104794847"
#
# === Stretch-004 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=33.3962, Rflop=3.94025e+12
# Evaluating Nfacet=2 -> DeltaW_stack=41.3001, Rflop=5.73324e+12
# Evaluating Nfacet=3 -> DeltaW_stack=48.5592, Rflop=7.4754e+12
# Nfacet=1, DeltaW_stack=33.3962  yielded the lowest value of Rflop=3.94025e+12
# Compute time:             13.73129 Nh
# Ingest visibility size:   138 GB
# Averaged visibility size: 8 GB
# Output size:              10 GB
# Fiducial frequency:       292.768844300699 MHz
# Beam size:                8.12358314384542"
# Pixel size:               2.70786104794847"
#
# === Stretch-004 SIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=158.635, Rflop=6.05017e+13
# Evaluating Nfacet=2 -> DeltaW_stack=199.525, Rflop=8.14715e+13
# Evaluating Nfacet=3 -> DeltaW_stack=238.032, Rflop=1.03762e+14
# Nfacet=1, DeltaW_stack=158.635  yielded the lowest value of Rflop=6.05017e+13
# Compute time:             210.8408 Nh
# Ingest visibility size:   121 GB
# Averaged visibility size: 21 GB
# Output size:              2681 GB
# Fiducial frequency:       253.609462524784 MHz
# Beam size:                9.37793103193789"
# Pixel size:               3.12597701064596"

# %%
with open(pipeline_config_output_path, "w") as f:
    json.dump(pipelines, f, indent=4)
with open(scheduling_block_types_config_output_path, "w") as f:
    json.dump(scheduling_block_types, f, indent=4)
