# %% [markdown]
# # Scheduling Model inputs for SV AA2 Mid
#
# Batch-generate scheduling and processing block data for use in scheduling experiments

# %%
import json
import sys
import yaml
import math
import tempfile
sys.path.insert(0, "..")
from sdp_par_model.config import PipelineConfig
from sdp_par_model.parameters.definitions import Constants

# %% [markdown]
# ## Specify output filenames

# %%
pipeline_config_output_path = "../data/output/sv_aas_mid_pipelines_v1.json"
scheduling_block_types_config_output_path = "../data/output/sv_aas_mid_scheduling_block_types_v1.json"

# %% [markdown]
# ## Load parameters
#
# Expected to be a list of parametric model configuration dictionaries.
#
# Can be generated from Google Sheets (Sheets to JSON -> Array of rows -> Download/Generate)

# %%
with open("../data/configs/stage_2/svaas_mid_v1.json") as stream:
    yamls = yaml.safe_load(stream)
print(f"Loaded {len(yamls)} pipeline configurations: {', '.join(yaml['name'] for yaml in yamls)}")
# Out:
# Loaded 73 pipeline configurations: SC-001 ICAL, SC-001 CIMG, SC-001 CIMG 2, SC-001 SIMG, SC-001 SIMG 2, SC-002 ICAL, SC-002 CIMG, SC-003 ICAL, SC-003 CIMG, SC-004 ICAL, SC-004 CIMG 1, SC-004 CIMG 2, SC-005 ICAL, SC-005 CIMG 1, SC-005 CIMG 2, SC-006 ICAL, SC-006 CIMG 1, SC-006 CIMG 2, SC-007 ICAL, SC-007 CIMG, SC-008 ICAL, SC-008 CIMG, SC-009 ICAL, SC-009 CIMG 1, SC-009 CIMG 2, SC-010 ICAL, SC-010 CIMG, SC-011 ICAL, SC-011 CIMG, SC-012 ICAL, SC-012 CIMG 1, SC-012 CIMG 2, SC-012 SIMG 1, SC-012 SIMG 2, SC-012 SIMG 3, SC-012 SIMG 4, SC-012 SIMG 5, SC-012 SIMG 6, SC-012 SIMG 7, SC-012 SIMG 8, SC-013 ICAL, SC-013 CIMG 1, SC-013 CIMG 2, SC-013 SIMG 1, SC-013 SIMG 2, SC-014 ICAL, SC-014 CIMG 1, SC-014 CIMG 2, SC-014 SIMG 1, SC-014 SIMG 2, SC-015 ICAL, SC-015 CIMG, SC-015 SIMG, SC-016 ICAL, SC-016 CIMG, SC-017 ICAL, SC-017 CIMG 1, SC-017 CIMG 2, SC-018 ICAL, SC-018 CIMG 1, SC-018 CIMG 2, SC-018 CIMG 3, SC-018 SIMG 1, SC-018 SIMG 2, SC-018 SIMG 3, SC-019 ICAL, SC-019 CIMG 1, SC-019 CIMG 2, SC-019 SIMG 1, SC-019 SIMG 2, SC-020 ICAL, SC-020 CIMG , SC-020 SIMG

# %% [markdown]
# ## Base assumptions
#
# We will likely need to revise this quite a bit to calibrate the appropriate level of "optimism". For the moment, let's keep with conservative estimates.

# %%
# Base assumptions
data_retention_hrs = 24.0
node_hours_uncertainty = 0.1
pct_parallelism = {
    "ICAL": 50.0,
    "DPrepA": 50.0,
    "DPrepB": 90.0,
}
pct_parallelism_max = {
    "ICAL": 75.0,
    "DPrepA": 75.0,
    "DPrepB": 95.0,
}
num_nodes = {
    "ICAL": 25,
    "DPrepA": 25,
    "DPrepB": 50,
}
    
# Extrapolation data
benchmark_node_hours = 30+8/60+26/60/60 # Strictly speaking using 3 nodes
Rflop_reference = 4324483174870.51
Tobs_ref = 8 * 3600

# %% [markdown]
# ## Generate configurations

# %%
pipelines = {}
scheduling_block_types = {}

for to_calculate in yamls:

    # Get name. Assume that everything up to first blank is the scheduling block definition name
    pip_name = to_calculate['name']
    sbd_name = pip_name.split(' ')[0]

    # Calculate parameters
    print('\n===',pip_name,'===')
    with tempfile.NamedTemporaryFile('w') as f:
        yaml.dump(to_calculate, f)
        pars = PipelineConfig(use_yaml=True, yaml_path=f.name).calc_tel_params(verbose=True)

    # Print
    node_hours = benchmark_node_hours * float(pars.Rflop * pars.Tobs) / (Rflop_reference * Tobs_ref)
    vis_size_gb = int(math.ceil(pars.Rvis_ingest*pars.Tobs/1e9))
    averaged_vis_size_gb = int(math.ceil(pars.Rvis(pars.Bmax, bcount=pars.Nbl_full)*pars.Tobs/1e9))
    output_size_gb = int(math.ceil(pars.Mout/1e9))
    print(f"Compute time:             {node_hours:.7} Nh")
    print(f"Ingest visibility size:   {vis_size_gb} GB")
    print(f"Averaged visibility size: {averaged_vis_size_gb} GB")
    print(f"Output size:              {output_size_gb} GB")
    print(f"Fiducial frequency:       {pars.c / pars.wl_sb_min / Constants.mega} MHz")
    #print(3 * (pars.c / 135e6) / 2 / 39e3 / 3 / Constants.arcsecond)
    print(f"Beam size:                {pars.Theta_beam / Constants.arcsecond}\"")
    print(f"Pixel size:               {pars.Theta_pix / Constants.arcsecond}\"")

    # Generate data
    if sbd_name not in scheduling_block_types:
        scheduling_block_types[sbd_name] = {
            "description": sbd_name,
            "short_name": sbd_name,
            "sampling_weight": pars.Tpoint / 3600,
            "scheduling_block_instance_time_hrs": pars.Tobs / 3600,
            "integration_time_hrs": max(pars.Tobs, pars.Tpoint) / 3600,
            "pipeline_steps": [],
            "raw_vis_gb": vis_size_gb,
            "processed_vis_gb": averaged_vis_size_gb,
            "data_retention_hrs": data_retention_hrs
        }

    # Add pipeline
    assert pip_name not in pipelines, f"Duplicated pipeline name {pip_name}!"
    scheduling_block_types[sbd_name]['pipeline_steps'].append(pip_name)
    pipelines[pip_name] = {
        "description": pip_name,
        "node_hours": node_hours,
        "node_hours_uncertainty": node_hours_uncertainty,
        "pct_parallelism": pct_parallelism[pars.pipeline],
        "pct_parallelism_max": pct_parallelism_max[pars.pipeline],
        "data_product_storage_gb": output_size_gb,
        "num_nodes": num_nodes[pars.pipeline]
    }
# Out:
# === SC-001 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2433.53, Rflop=4.57172e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3272.86, Rflop=5.52245e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3934.87, Rflop=6.26995e+13
# Nfacet=1, DeltaW_stack=2433.53  yielded the lowest value of Rflop=4.57172e+13
# Compute time:             318.6377 Nh
# Ingest visibility size:   8858 GB
# Averaged visibility size: 771 GB
# Output size:              0 GB
# Fiducial frequency:       6572.19847297220 MHz
# Beam size:                0.392034171911236"
# Pixel size:               0.130678057303745"
#
# === SC-001 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=933.05, Rflop=4.56337e+13
# Evaluating Nfacet=2 -> DeltaW_stack=1215.74, Rflop=7.273e+13
# Evaluating Nfacet=3 -> DeltaW_stack=1472.18, Rflop=1.07843e+14
# Nfacet=1, DeltaW_stack=933.05  yielded the lowest value of Rflop=4.56337e+13
# Compute time:             318.0552 Nh
# Ingest visibility size:   8858 GB
# Averaged visibility size: 771 GB
# Output size:              56 GB
# Fiducial frequency:       6572.19847297220 MHz
# Beam size:                0.392034171911236"
# Pixel size:               0.130678057303745"
#
# === SC-001 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=507.731, Rflop=4.89228e+12
# Evaluating Nfacet=2 -> DeltaW_stack=613.308, Rflop=1.01938e+13
# Evaluating Nfacet=3 -> DeltaW_stack=709.815, Rflop=1.8614e+13
# Nfacet=1, DeltaW_stack=507.731  yielded the lowest value of Rflop=4.89228e+12
# Compute time:             34.09795 Nh
# Ingest visibility size:   2229 GB
# Averaged visibility size: 86 GB
# Output size:              7 GB
# Fiducial frequency:       6572.19847297220 MHz
# Beam size:                1.17610251573371"
# Pixel size:               0.392034171911236"
#
# === SC-001 SIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=10143.3, Rflop=3.76404e+12
# Evaluating Nfacet=2 -> DeltaW_stack=12791.9, Rflop=4.7322e+12
# Evaluating Nfacet=3 -> DeltaW_stack=19650.7, Rflop=5.2019e+12
# Nfacet=1, DeltaW_stack=10143.3  yielded the lowest value of Rflop=3.76404e+12
# Compute time:             26.23438 Nh
# Ingest visibility size:   8109 GB
# Averaged visibility size: 26 GB
# Output size:              131 GB
# Fiducial frequency:       8399.39031028771 MHz
# Beam size:                0.306751596342913"
# Pixel size:               0.102250532114304"
#
# === SC-001 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=7264.6, Rflop=4.17268e+11
# Evaluating Nfacet=2 -> DeltaW_stack=7264.6, Rflop=6.69053e+11
# Evaluating Nfacet=3 -> DeltaW_stack=7264.6, Rflop=1.02101e+12
# Nfacet=1, DeltaW_stack=7264.6  yielded the lowest value of Rflop=4.17268e+11
# Compute time:             2.908255 Nh
# Ingest visibility size:   2040 GB
# Averaged visibility size: 3 GB
# Output size:              15 GB
# Fiducial frequency:       8399.39031028771 MHz
# Beam size:                0.920254789028738"
# Pixel size:               0.306751596342913"
#
# === SC-002 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=159.853, Rflop=8.80706e+13
# Evaluating Nfacet=2 -> DeltaW_stack=220.938, Rflop=9.83594e+13
# Evaluating Nfacet=3 -> DeltaW_stack=279.506, Rflop=9.65011e+13
# Evaluating Nfacet=4 -> DeltaW_stack=326.093, Rflop=1.05691e+14
# Evaluating Nfacet=5 -> DeltaW_stack=363.754, Rflop=1.22212e+14
# Nfacet=1, DeltaW_stack=159.853  yielded the lowest value of Rflop=8.80706e+13
# Compute time:             153.4574 Nh
# Ingest visibility size:   2218 GB
# Averaged visibility size: 196 GB
# Output size:              0 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-002 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=72.9104, Rflop=6.97327e+13
# Evaluating Nfacet=2 -> DeltaW_stack=96.1525, Rflop=9.8359e+13
# Evaluating Nfacet=3 -> DeltaW_stack=117.153, Rflop=1.28994e+14
# Nfacet=1, DeltaW_stack=72.9104  yielded the lowest value of Rflop=6.97327e+13
# Compute time:             121.5049 Nh
# Ingest visibility size:   2218 GB
# Averaged visibility size: 196 GB
# Output size:              10 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-003 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2431.82, Rflop=4.66862e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3148.84, Rflop=5.64439e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3931.44, Rflop=6.42776e+13
# Nfacet=1, DeltaW_stack=2431.82  yielded the lowest value of Rflop=4.66862e+13
# Compute time:             122.0217 Nh
# Ingest visibility size:   3329 GB
# Averaged visibility size: 296 GB
# Output size:              0 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-003 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=931.795, Rflop=4.65798e+13
# Evaluating Nfacet=2 -> DeltaW_stack=1214.02, Rflop=7.43032e+13
# Evaluating Nfacet=3 -> DeltaW_stack=1470.07, Rflop=1.10271e+14
# Nfacet=1, DeltaW_stack=931.795  yielded the lowest value of Rflop=4.65798e+13
# Compute time:             121.7437 Nh
# Ingest visibility size:   3329 GB
# Averaged visibility size: 296 GB
# Output size:              10 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-004 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=159.853, Rflop=8.7834e+13
# Evaluating Nfacet=2 -> DeltaW_stack=220.938, Rflop=9.79809e+13
# Evaluating Nfacet=3 -> DeltaW_stack=279.506, Rflop=9.58866e+13
# Evaluating Nfacet=4 -> DeltaW_stack=326.093, Rflop=1.04746e+14
# Evaluating Nfacet=5 -> DeltaW_stack=363.754, Rflop=1.20842e+14
# Nfacet=1, DeltaW_stack=159.853  yielded the lowest value of Rflop=8.7834e+13
# Compute time:             612.1809 Nh
# Ingest visibility size:   8871 GB
# Averaged visibility size: 784 GB
# Output size:              0 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-004 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=72.9104, Rflop=6.97033e+13
# Evaluating Nfacet=2 -> DeltaW_stack=96.1525, Rflop=9.83119e+13
# Evaluating Nfacet=3 -> DeltaW_stack=117.153, Rflop=1.28918e+14
# Nfacet=1, DeltaW_stack=72.9104  yielded the lowest value of Rflop=6.97033e+13
# Compute time:             485.8141 Nh
# Ingest visibility size:   8871 GB
# Averaged visibility size: 784 GB
# Output size:              57 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-004 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=45.3023, Rflop=1.02892e+13
# Evaluating Nfacet=2 -> DeltaW_stack=55.2082, Rflop=1.85359e+13
# Evaluating Nfacet=3 -> DeltaW_stack=64.12, Rflop=3.05318e+13
# Nfacet=1, DeltaW_stack=45.3023  yielded the lowest value of Rflop=1.02892e+13
# Compute time:             71.71318 Nh
# Ingest visibility size:   2975 GB
# Averaged visibility size: 137 GB
# Output size:              10 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                4.53522540442443"
# Pixel size:               1.51174180147481"
#
# === SC-005 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=31.5634, Rflop=2.05436e+14
# Evaluating Nfacet=2 -> DeltaW_stack=43.7951, Rflop=2.23514e+14
# Evaluating Nfacet=3 -> DeltaW_stack=55.7157, Rflop=2.09792e+14
# Evaluating Nfacet=4 -> DeltaW_stack=65.2788, Rflop=2.21282e+14
# Evaluating Nfacet=5 -> DeltaW_stack=73.0326, Rflop=2.48288e+14
# Nfacet=1, DeltaW_stack=31.5634  yielded the lowest value of Rflop=2.05436e+14
# Compute time:             1431.837 Nh
# Ingest visibility size:   9191 GB
# Averaged visibility size: 1513 GB
# Output size:              0 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-005 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=14.5009, Rflop=1.54883e+14
# Evaluating Nfacet=2 -> DeltaW_stack=19.2055, Rflop=2.10249e+14
# Evaluating Nfacet=3 -> DeltaW_stack=23.4639, Rflop=2.63976e+14
# Nfacet=1, DeltaW_stack=14.5009  yielded the lowest value of Rflop=1.54883e+14
# Compute time:             1079.492 Nh
# Ingest visibility size:   9191 GB
# Averaged visibility size: 1513 GB
# Output size:              87 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-005 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=9.02243, Rflop=2.2041e+13
# Evaluating Nfacet=2 -> DeltaW_stack=11.0257, Rflop=3.81449e+13
# Evaluating Nfacet=3 -> DeltaW_stack=12.8218, Rflop=6.07516e+13
# Nfacet=1, DeltaW_stack=9.02243  yielded the lowest value of Rflop=2.2041e+13
# Compute time:             153.62 Nh
# Ingest visibility size:   3082 GB
# Averaged visibility size: 263 GB
# Output size:              15 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                10.2670665211120"
# Pixel size:               3.42235550703734"
#
# === SC-006 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=159.853, Rflop=8.7834e+13
# Evaluating Nfacet=2 -> DeltaW_stack=220.938, Rflop=9.79809e+13
# Evaluating Nfacet=3 -> DeltaW_stack=279.506, Rflop=9.58866e+13
# Evaluating Nfacet=4 -> DeltaW_stack=326.093, Rflop=1.04746e+14
# Evaluating Nfacet=5 -> DeltaW_stack=363.754, Rflop=1.20842e+14
# Nfacet=1, DeltaW_stack=159.853  yielded the lowest value of Rflop=8.7834e+13
# Compute time:             612.1809 Nh
# Ingest visibility size:   8871 GB
# Averaged visibility size: 784 GB
# Output size:              0 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-006 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=72.9104, Rflop=6.97033e+13
# Evaluating Nfacet=2 -> DeltaW_stack=96.1525, Rflop=9.83119e+13
# Evaluating Nfacet=3 -> DeltaW_stack=117.153, Rflop=1.28918e+14
# Nfacet=1, DeltaW_stack=72.9104  yielded the lowest value of Rflop=6.97033e+13
# Compute time:             485.8141 Nh
# Ingest visibility size:   8871 GB
# Averaged visibility size: 784 GB
# Output size:              57 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-006 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=30.9803, Rflop=2.86337e+12
# Evaluating Nfacet=2 -> DeltaW_stack=37.4873, Rflop=5.8979e+12
# Evaluating Nfacet=3 -> DeltaW_stack=43.3894, Rflop=1.05839e+13
# Nfacet=1, DeltaW_stack=30.9803  yielded the lowest value of Rflop=2.86337e+12
# Compute time:             19.95694 Nh
# Ingest visibility size:   1350 GB
# Averaged visibility size: 39 GB
# Output size:              3 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                8.50354763329580"
# Pixel size:               2.83451587776527"
#
# === SC-007 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=6629.65, Rflop=3.82729e+13
# Evaluating Nfacet=2 -> DeltaW_stack=8816.37, Rflop=4.85015e+13
# Evaluating Nfacet=3 -> DeltaW_stack=10538.5, Rflop=5.8317e+13
# Nfacet=1, DeltaW_stack=6629.65  yielded the lowest value of Rflop=3.82729e+13
# Compute time:             266.7526 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              0 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-007 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2409.8, Rflop=4.24988e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3128.6, Rflop=7.01896e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3782.99, Rflop=1.07389e+14
# Nfacet=1, DeltaW_stack=2409.8  yielded the lowest value of Rflop=4.24988e+13
# Compute time:             296.2061 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              40 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-008 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=6629.65, Rflop=3.82729e+13
# Evaluating Nfacet=2 -> DeltaW_stack=8816.37, Rflop=4.85015e+13
# Evaluating Nfacet=3 -> DeltaW_stack=10538.5, Rflop=5.8317e+13
# Nfacet=1, DeltaW_stack=6629.65  yielded the lowest value of Rflop=3.82729e+13
# Compute time:             266.7526 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              0 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-008 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2409.8, Rflop=4.24988e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3128.6, Rflop=7.01896e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3782.99, Rflop=1.07389e+14
# Nfacet=1, DeltaW_stack=2409.8  yielded the lowest value of Rflop=4.24988e+13
# Compute time:             296.2061 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              57 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-009 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=6629.65, Rflop=3.82729e+13
# Evaluating Nfacet=2 -> DeltaW_stack=8816.37, Rflop=4.85015e+13
# Evaluating Nfacet=3 -> DeltaW_stack=10538.5, Rflop=5.8317e+13
# Nfacet=1, DeltaW_stack=6629.65  yielded the lowest value of Rflop=3.82729e+13
# Compute time:             266.7526 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              0 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-009 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2409.8, Rflop=4.24988e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3128.6, Rflop=7.01896e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3782.99, Rflop=1.07389e+14
# Nfacet=1, DeltaW_stack=2409.8  yielded the lowest value of Rflop=4.24988e+13
# Compute time:             296.2061 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              7 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-009 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=1086.29, Rflop=2.80095e+12
# Evaluating Nfacet=2 -> DeltaW_stack=1307.93, Rflop=6.33215e+12
# Evaluating Nfacet=3 -> DeltaW_stack=1511.58, Rflop=1.20609e+13
# Nfacet=1, DeltaW_stack=1086.29  yielded the lowest value of Rflop=2.80095e+12
# Compute time:             19.52192 Nh
# Ingest visibility size:   1561 GB
# Averaged visibility size: 50 GB
# Output size:              1 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.861933349962489"
# Pixel size:               0.287311116654163"
#
# === SC-010 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=6629.65, Rflop=3.82729e+13
# Evaluating Nfacet=2 -> DeltaW_stack=8816.37, Rflop=4.85015e+13
# Evaluating Nfacet=3 -> DeltaW_stack=10538.5, Rflop=5.8317e+13
# Nfacet=1, DeltaW_stack=6629.65  yielded the lowest value of Rflop=3.82729e+13
# Compute time:             266.7526 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              0 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-010 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2409.8, Rflop=4.24988e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3128.6, Rflop=7.01896e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3782.99, Rflop=1.07389e+14
# Nfacet=1, DeltaW_stack=2409.8  yielded the lowest value of Rflop=4.24988e+13
# Compute time:             296.2061 Nh
# Ingest visibility size:   8881 GB
# Averaged visibility size: 795 GB
# Output size:              3 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-011 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2431.82, Rflop=4.65548e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3148.84, Rflop=5.62337e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3931.44, Rflop=6.39362e+13
# Nfacet=1, DeltaW_stack=2431.82  yielded the lowest value of Rflop=4.65548e+13
# Compute time:             324.4753 Nh
# Ingest visibility size:   8875 GB
# Averaged visibility size: 789 GB
# Output size:              0 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-011 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=931.795, Rflop=4.65635e+13
# Evaluating Nfacet=2 -> DeltaW_stack=1214.02, Rflop=7.4277e+13
# Evaluating Nfacet=3 -> DeltaW_stack=1470.07, Rflop=1.10229e+14
# Nfacet=1, DeltaW_stack=931.795  yielded the lowest value of Rflop=4.65635e+13
# Compute time:             324.5356 Nh
# Ingest visibility size:   8875 GB
# Averaged visibility size: 789 GB
# Output size:              3 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-012 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=31.5634, Rflop=2.05541e+14
# Evaluating Nfacet=2 -> DeltaW_stack=43.7951, Rflop=2.23682e+14
# Evaluating Nfacet=3 -> DeltaW_stack=55.7157, Rflop=2.10066e+14
# Evaluating Nfacet=4 -> DeltaW_stack=65.2788, Rflop=2.21702e+14
# Evaluating Nfacet=5 -> DeltaW_stack=73.0326, Rflop=2.48897e+14
# Nfacet=1, DeltaW_stack=31.5634  yielded the lowest value of Rflop=2.05541e+14
# Compute time:             716.2851 Nh
# Ingest visibility size:   4596 GB
# Averaged visibility size: 757 GB
# Output size:              0 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-012 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=14.5009, Rflop=1.54896e+14
# Evaluating Nfacet=2 -> DeltaW_stack=19.2055, Rflop=2.1027e+14
# Evaluating Nfacet=3 -> DeltaW_stack=23.4639, Rflop=2.6401e+14
# Nfacet=1, DeltaW_stack=14.5009  yielded the lowest value of Rflop=1.54896e+14
# Compute time:             539.792 Nh
# Ingest visibility size:   4596 GB
# Averaged visibility size: 757 GB
# Output size:              1 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-012 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=8.01456, Rflop=1.35695e+13
# Evaluating Nfacet=2 -> DeltaW_stack=9.76416, Rflop=2.44375e+13
# Evaluating Nfacet=3 -> DeltaW_stack=11.3376, Rflop=4.01448e+13
# Nfacet=1, DeltaW_stack=8.01456  yielded the lowest value of Rflop=1.35695e+13
# Compute time:             47.28811 Nh
# Ingest visibility size:   1157 GB
# Averaged visibility size: 85 GB
# Output size:              1 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                12.8338331513900"
# Pixel size:               4.27794438379668"
#
# === SC-012 SIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=210.843, Rflop=9.22654e+13
# Evaluating Nfacet=2 -> DeltaW_stack=373.016, Rflop=9.6137e+13
# Evaluating Nfacet=3 -> DeltaW_stack=486.884, Rflop=8.07622e+13
# Evaluating Nfacet=4 -> DeltaW_stack=565.438, Rflop=7.93954e+13
# Evaluating Nfacet=5 -> DeltaW_stack=644.872, Rflop=8.49925e+13
# Evaluating Nfacet=6 -> DeltaW_stack=731.089, Rflop=9.21678e+13
# Nfacet=4, DeltaW_stack=565.438  yielded the lowest value of Rflop=7.93954e+13
# Compute time:             276.6828 Nh
# Ingest visibility size:   4014 GB
# Averaged visibility size: 39 GB
# Output size:              21 GB
# Fiducial frequency:       854.588342168517 MHz
# Beam size:                3.01493275633742"
# Pixel size:               1.00497758544581"
#
# === SC-012 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=90.0112, Rflop=1.11779e+13
# Evaluating Nfacet=2 -> DeltaW_stack=112.891, Rflop=1.54691e+13
# Evaluating Nfacet=3 -> DeltaW_stack=133.429, Rflop=1.99916e+13
# Nfacet=1, DeltaW_stack=90.0112  yielded the lowest value of Rflop=1.11779e+13
# Compute time:             38.95374 Nh
# Ingest visibility size:   1010 GB
# Averaged visibility size: 13 GB
# Output size:              2 GB
# Fiducial frequency:       854.588342168517 MHz
# Beam size:                9.04479826901225"
# Pixel size:               3.01493275633742"
#
# === SC-012 SIMG 3 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=222.224, Rflop=9.06049e+13
# Evaluating Nfacet=2 -> DeltaW_stack=393.14, Rflop=9.40525e+13
# Evaluating Nfacet=3 -> DeltaW_stack=513.111, Rflop=7.9356e+13
# Evaluating Nfacet=4 -> DeltaW_stack=595.833, Rflop=7.83348e+13
# Evaluating Nfacet=5 -> DeltaW_stack=679.468, Rflop=8.4091e+13
# Evaluating Nfacet=6 -> DeltaW_stack=770.251, Rflop=9.1425e+13
# Nfacet=4, DeltaW_stack=595.833  yielded the lowest value of Rflop=7.83348e+13
# Compute time:             272.9867 Nh
# Ingest visibility size:   4014 GB
# Averaged visibility size: 39 GB
# Output size:              21 GB
# Fiducial frequency:       882.628395036620 MHz
# Beam size:                2.91915193356208"
# Pixel size:               0.973050644520695"
#
# === SC-012 SIMG 4 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=94.866, Rflop=1.10489e+13
# Evaluating Nfacet=2 -> DeltaW_stack=118.955, Rflop=1.53288e+13
# Evaluating Nfacet=3 -> DeltaW_stack=140.564, Rflop=1.98781e+13
# Nfacet=1, DeltaW_stack=94.866  yielded the lowest value of Rflop=1.10489e+13
# Compute time:             38.50396 Nh
# Ingest visibility size:   1010 GB
# Averaged visibility size: 13 GB
# Output size:              2 GB
# Fiducial frequency:       882.628395036620 MHz
# Beam size:                8.75745580068625"
# Pixel size:               2.91915193356208"
#
# === SC-012 SIMG 5 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=222.655, Rflop=9.05444e+13
# Evaluating Nfacet=2 -> DeltaW_stack=393.901, Rflop=9.39771e+13
# Evaluating Nfacet=3 -> DeltaW_stack=514.103, Rflop=7.93051e+13
# Evaluating Nfacet=4 -> DeltaW_stack=596.983, Rflop=7.82963e+13
# Evaluating Nfacet=5 -> DeltaW_stack=680.777, Rflop=8.40583e+13
# Evaluating Nfacet=6 -> DeltaW_stack=771.732, Rflop=9.1398e+13
# Nfacet=4, DeltaW_stack=596.983  yielded the lowest value of Rflop=7.82963e+13
# Compute time:             272.8526 Nh
# Ingest visibility size:   4014 GB
# Averaged visibility size: 39 GB
# Output size:              21 GB
# Fiducial frequency:       883.678396950927 MHz
# Beam size:                2.91568334688059"
# Pixel size:               0.971894448960195"
#
# === SC-012 SIMG 6 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=95.0497, Rflop=1.10442e+13
# Evaluating Nfacet=2 -> DeltaW_stack=119.184, Rflop=1.53237e+13
# Evaluating Nfacet=3 -> DeltaW_stack=140.834, Rflop=1.9874e+13
# Nfacet=1, DeltaW_stack=95.0497  yielded the lowest value of Rflop=1.10442e+13
# Compute time:             38.48758 Nh
# Ingest visibility size:   1010 GB
# Averaged visibility size: 13 GB
# Output size:              2 GB
# Fiducial frequency:       883.678396950927 MHz
# Beam size:                8.74705004064175"
# Pixel size:               2.91568334688059"
#
# === SC-012 SIMG 7 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=234.256, Rflop=8.89739e+13
# Evaluating Nfacet=2 -> DeltaW_stack=414.414, Rflop=9.20308e+13
# Evaluating Nfacet=3 -> DeltaW_stack=540.834, Rflop=7.79891e+13
# Evaluating Nfacet=4 -> DeltaW_stack=627.959, Rflop=7.7301e+13
# Evaluating Nfacet=5 -> DeltaW_stack=716.03, Rflop=8.3212e+13
# Evaluating Nfacet=6 -> DeltaW_stack=811.634, Rflop=9.06998e+13
# Nfacet=4, DeltaW_stack=627.959  yielded the lowest value of Rflop=7.7301e+13
# Compute time:             269.3842 Nh
# Ingest visibility size:   4014 GB
# Averaged visibility size: 39 GB
# Output size:              21 GB
# Fiducial frequency:       911.678446366487 MHz
# Beam size:                2.82613502190026"
# Pixel size:               0.942045007300087"
#
# === SC-012 SIMG 8 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=99.9983, Rflop=1.09221e+13
# Evaluating Nfacet=2 -> DeltaW_stack=125.364, Rflop=1.5191e+13
# Evaluating Nfacet=3 -> DeltaW_stack=148.103, Rflop=1.97666e+13
# Nfacet=1, DeltaW_stack=99.9983  yielded the lowest value of Rflop=1.09221e+13
# Compute time:             38.06217 Nh
# Ingest visibility size:   1010 GB
# Averaged visibility size: 13 GB
# Output size:              2 GB
# Fiducial frequency:       911.678446366487 MHz
# Beam size:                8.47840506570079"
# Pixel size:               2.82613502190026"
#
# === SC-013 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=159.853, Rflop=8.79129e+13
# Evaluating Nfacet=2 -> DeltaW_stack=220.938, Rflop=9.81071e+13
# Evaluating Nfacet=3 -> DeltaW_stack=279.506, Rflop=9.60915e+13
# Evaluating Nfacet=4 -> DeltaW_stack=326.093, Rflop=1.05061e+14
# Evaluating Nfacet=5 -> DeltaW_stack=363.754, Rflop=1.21299e+14
# Nfacet=1, DeltaW_stack=159.853  yielded the lowest value of Rflop=8.79129e+13
# Compute time:             306.3653 Nh
# Ingest visibility size:   4436 GB
# Averaged visibility size: 392 GB
# Output size:              0 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-013 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=72.9104, Rflop=6.97131e+13
# Evaluating Nfacet=2 -> DeltaW_stack=96.1525, Rflop=9.83276e+13
# Evaluating Nfacet=3 -> DeltaW_stack=117.153, Rflop=1.28943e+14
# Nfacet=1, DeltaW_stack=72.9104  yielded the lowest value of Rflop=6.97131e+13
# Compute time:             242.9413 Nh
# Ingest visibility size:   4436 GB
# Averaged visibility size: 392 GB
# Output size:              57 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-013 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=40.2284, Rflop=6.39738e+12
# Evaluating Nfacet=2 -> DeltaW_stack=48.8906, Rflop=1.19724e+13
# Evaluating Nfacet=3 -> DeltaW_stack=56.7082, Rflop=2.02695e+13
# Nfacet=1, DeltaW_stack=40.2284  yielded the lowest value of Rflop=6.39738e+12
# Compute time:             22.29406 Nh
# Ingest visibility size:   1116 GB
# Averaged visibility size: 44 GB
# Output size:              7 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                5.66903175553053"
# Pixel size:               1.88967725184351"
#
# === SC-013 SIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=261.004, Rflop=2.00716e+13
# Evaluating Nfacet=2 -> DeltaW_stack=369.908, Rflop=2.26868e+13
# Evaluating Nfacet=3 -> DeltaW_stack=458.215, Rflop=2.27203e+13
# Nfacet=1, DeltaW_stack=261.004  yielded the lowest value of Rflop=2.00716e+13
# Compute time:             69.94698 Nh
# Ingest visibility size:   4223 GB
# Averaged visibility size: 62 GB
# Output size:              154 GB
# Fiducial frequency:       1497.92099692186 MHz
# Beam size:                1.72006827548486"
# Pixel size:               0.573356091828286"
#
# === SC-013 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=147.513, Rflop=1.74596e+12
# Evaluating Nfacet=2 -> DeltaW_stack=183.624, Rflop=2.4781e+12
# Evaluating Nfacet=3 -> DeltaW_stack=215.533, Rflop=3.30717e+12
# Nfacet=1, DeltaW_stack=147.513  yielded the lowest value of Rflop=1.74596e+12
# Compute time:             6.084444 Nh
# Ingest visibility size:   1063 GB
# Averaged visibility size: 7 GB
# Output size:              18 GB
# Fiducial frequency:       1497.92099692186 MHz
# Beam size:                5.16020482645457"
# Pixel size:               1.72006827548486"
#
# === SC-014 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=31.5634, Rflop=2.05541e+14
# Evaluating Nfacet=2 -> DeltaW_stack=43.7951, Rflop=2.23682e+14
# Evaluating Nfacet=3 -> DeltaW_stack=55.7157, Rflop=2.10066e+14
# Evaluating Nfacet=4 -> DeltaW_stack=65.2788, Rflop=2.21702e+14
# Evaluating Nfacet=5 -> DeltaW_stack=73.0326, Rflop=2.48897e+14
# Nfacet=1, DeltaW_stack=31.5634  yielded the lowest value of Rflop=2.05541e+14
# Compute time:             716.2851 Nh
# Ingest visibility size:   4596 GB
# Averaged visibility size: 757 GB
# Output size:              0 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-014 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=14.5009, Rflop=1.54896e+14
# Evaluating Nfacet=2 -> DeltaW_stack=19.2055, Rflop=2.1027e+14
# Evaluating Nfacet=3 -> DeltaW_stack=23.4639, Rflop=2.6401e+14
# Nfacet=1, DeltaW_stack=14.5009  yielded the lowest value of Rflop=1.54896e+14
# Compute time:             539.792 Nh
# Ingest visibility size:   4596 GB
# Averaged visibility size: 757 GB
# Output size:              1 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-014 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=8.01456, Rflop=1.35695e+13
# Evaluating Nfacet=2 -> DeltaW_stack=9.76416, Rflop=2.44375e+13
# Evaluating Nfacet=3 -> DeltaW_stack=11.3376, Rflop=4.01448e+13
# Nfacet=1, DeltaW_stack=8.01456  yielded the lowest value of Rflop=1.35695e+13
# Compute time:             47.28811 Nh
# Ingest visibility size:   1157 GB
# Averaged visibility size: 85 GB
# Output size:              1 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                12.8338331513900"
# Pixel size:               4.27794438379668"
#
# === SC-014 SIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=167.39, Rflop=9.99807e+13
# Evaluating Nfacet=2 -> DeltaW_stack=296.174, Rflop=1.06179e+14
# Evaluating Nfacet=3 -> DeltaW_stack=367.426, Rflop=8.71571e+13
# Evaluating Nfacet=4 -> DeltaW_stack=449.3, Rflop=8.44342e+13
# Evaluating Nfacet=5 -> DeltaW_stack=494.51, Rflop=8.91098e+13
# Evaluating Nfacet=6 -> DeltaW_stack=581.384, Rflop=9.56788e+13
# Nfacet=4, DeltaW_stack=449.3  yielded the lowest value of Rflop=8.44342e+13
# Compute time:             294.2427 Nh
# Ingest visibility size:   4015 GB
# Averaged visibility size: 39 GB
# Output size:              21 GB
# Fiducial frequency:       741.678088641043 MHz
# Beam size:                3.47391466115555"
# Pixel size:               1.15797155371852"
#
# === SC-014 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=71.4711, Rflop=1.17776e+13
# Evaluating Nfacet=2 -> DeltaW_stack=89.7189, Rflop=1.61203e+13
# Evaluating Nfacet=3 -> DeltaW_stack=106.146, Rflop=2.05181e+13
# Nfacet=1, DeltaW_stack=71.4711  yielded the lowest value of Rflop=1.17776e+13
# Compute time:             41.0435 Nh
# Ingest visibility size:   1011 GB
# Averaged visibility size: 13 GB
# Output size:              2 GB
# Fiducial frequency:       741.678088641043 MHz
# Beam size:                10.4217439834667"
# Pixel size:               3.47391466115555"
#
# === SC-015 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2431.82, Rflop=4.66337e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3148.84, Rflop=5.63598e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3931.44, Rflop=6.4141e+13
# Nfacet=1, DeltaW_stack=2431.82  yielded the lowest value of Rflop=4.66337e+13
# Compute time:             162.5124 Nh
# Ingest visibility size:   4438 GB
# Averaged visibility size: 395 GB
# Output size:              0 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-015 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=931.795, Rflop=4.65733e+13
# Evaluating Nfacet=2 -> DeltaW_stack=1214.02, Rflop=7.42927e+13
# Evaluating Nfacet=3 -> DeltaW_stack=1470.07, Rflop=1.10254e+14
# Nfacet=1, DeltaW_stack=931.795  yielded the lowest value of Rflop=4.65733e+13
# Compute time:             162.302 Nh
# Ingest visibility size:   4438 GB
# Averaged visibility size: 395 GB
# Output size:              57 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-015 SIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=8794.16, Rflop=4.63666e+13
# Evaluating Nfacet=2 -> DeltaW_stack=14811.4, Rflop=5.63943e+13
# Evaluating Nfacet=3 -> DeltaW_stack=14811.4, Rflop=6.38451e+13
# Nfacet=1, DeltaW_stack=8794.16  yielded the lowest value of Rflop=4.63666e+13
# Compute time:             161.5817 Nh
# Ingest visibility size:   4007 GB
# Averaged visibility size: 76 GB
# Output size:              3118 GB
# Fiducial frequency:       5640.41998436054 MHz
# Beam size:                0.456796903977365"
# Pixel size:               0.152265634659122"
#
# === SC-016 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2431.82, Rflop=4.65548e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3148.84, Rflop=5.62337e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3931.44, Rflop=6.39362e+13
# Nfacet=1, DeltaW_stack=2431.82  yielded the lowest value of Rflop=4.65548e+13
# Compute time:             324.4753 Nh
# Ingest visibility size:   8875 GB
# Averaged visibility size: 789 GB
# Output size:              0 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-016 CIMG ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=931.795, Rflop=4.65635e+13
# Evaluating Nfacet=2 -> DeltaW_stack=1214.02, Rflop=7.4277e+13
# Evaluating Nfacet=3 -> DeltaW_stack=1470.07, Rflop=1.10229e+14
# Nfacet=1, DeltaW_stack=931.795  yielded the lowest value of Rflop=4.65635e+13
# Compute time:             324.5356 Nh
# Ingest visibility size:   8875 GB
# Averaged visibility size: 789 GB
# Output size:              1 GB
# Fiducial frequency:       6612.70232461120 MHz
# Beam size:                0.389632900364895"
# Pixel size:               0.129877633454965"
#
# === SC-017 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=88.9938, Rflop=6.89665e+12
# Evaluating Nfacet=2 -> DeltaW_stack=110.957, Rflop=9.73734e+12
# Evaluating Nfacet=3 -> DeltaW_stack=130.279, Rflop=1.28294e+13
# Nfacet=1, DeltaW_stack=88.9938  yielded the lowest value of Rflop=6.89665e+12
# Compute time:             48.06791 Nh
# Ingest visibility size:   2232 GB
# Averaged visibility size: 88 GB
# Output size:              0 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                5.66903175553053"
# Pixel size:               1.88967725184351"
#
# === SC-017 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=40.2284, Rflop=6.38774e+12
# Evaluating Nfacet=2 -> DeltaW_stack=48.8906, Rflop=1.1957e+13
# Evaluating Nfacet=3 -> DeltaW_stack=56.7082, Rflop=2.02444e+13
# Nfacet=1, DeltaW_stack=40.2284  yielded the lowest value of Rflop=6.38774e+12
# Compute time:             44.52093 Nh
# Ingest visibility size:   2232 GB
# Averaged visibility size: 88 GB
# Output size:              1 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                5.66903175553053"
# Pixel size:               1.88967725184351"
#
# === SC-017 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=25.1993, Rflop=1.68841e+12
# Evaluating Nfacet=2 -> DeltaW_stack=30.4095, Rflop=3.7642e+12
# Evaluating Nfacet=3 -> DeltaW_stack=35.1498, Rflop=7.03584e+12
# Nfacet=1, DeltaW_stack=25.1993  yielded the lowest value of Rflop=1.68841e+12
# Compute time:             11.7678 Nh
# Ingest visibility size:   929 GB
# Averaged visibility size: 22 GB
# Output size:              1 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                11.3380635110611"
# Pixel size:               3.77935450368702"
#
# === SC-018 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=159.853, Rflop=8.79129e+13
# Evaluating Nfacet=2 -> DeltaW_stack=220.938, Rflop=9.81071e+13
# Evaluating Nfacet=3 -> DeltaW_stack=279.506, Rflop=9.60915e+13
# Evaluating Nfacet=4 -> DeltaW_stack=326.093, Rflop=1.05061e+14
# Evaluating Nfacet=5 -> DeltaW_stack=363.754, Rflop=1.21299e+14
# Nfacet=1, DeltaW_stack=159.853  yielded the lowest value of Rflop=8.79129e+13
# Compute time:             306.3653 Nh
# Ingest visibility size:   4436 GB
# Averaged visibility size: 392 GB
# Output size:              0 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-018 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=72.9104, Rflop=6.97131e+13
# Evaluating Nfacet=2 -> DeltaW_stack=96.1525, Rflop=9.83276e+13
# Evaluating Nfacet=3 -> DeltaW_stack=117.153, Rflop=1.28943e+14
# Nfacet=1, DeltaW_stack=72.9104  yielded the lowest value of Rflop=6.97131e+13
# Compute time:             242.9413 Nh
# Ingest visibility size:   4436 GB
# Averaged visibility size: 392 GB
# Output size:              57 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                1.88967725184351"
# Pixel size:               0.629892417281170"
#
# === SC-018 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=40.2284, Rflop=6.39738e+12
# Evaluating Nfacet=2 -> DeltaW_stack=48.8906, Rflop=1.19724e+13
# Evaluating Nfacet=3 -> DeltaW_stack=56.7082, Rflop=2.02695e+13
# Nfacet=1, DeltaW_stack=40.2284  yielded the lowest value of Rflop=6.39738e+12
# Compute time:             22.29406 Nh
# Ingest visibility size:   1116 GB
# Averaged visibility size: 44 GB
# Output size:              7 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                5.66903175553053"
# Pixel size:               1.88967725184351"
#
# === SC-018 CIMG 3 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=18.6857, Rflop=8.43849e+11
# Evaluating Nfacet=2 -> DeltaW_stack=22.476, Rflop=2.08806e+12
# Evaluating Nfacet=3 -> DeltaW_stack=25.9347, Rflop=4.08973e+12
# Nfacet=1, DeltaW_stack=18.6857  yielded the lowest value of Rflop=8.43849e+11
# Compute time:             2.940708 Nh
# Ingest visibility size:   237 GB
# Averaged visibility size: 5 GB
# Output size:              1 GB
# Fiducial frequency:       1363.47430942208 MHz
# Beam size:                17.0070952665916"
# Pixel size:               5.66903175553053"
#
# === SC-018 SIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=872.83, Rflop=1.79313e+14
# Evaluating Nfacet=2 -> DeltaW_stack=1161.64, Rflop=1.94147e+14
# Evaluating Nfacet=3 -> DeltaW_stack=1386.85, Rflop=1.83523e+14
# Evaluating Nfacet=4 -> DeltaW_stack=1796.7, Rflop=1.96938e+14
# Evaluating Nfacet=5 -> DeltaW_stack=1971.32, Rflop=2.25049e+14
# Nfacet=1, DeltaW_stack=872.83  yielded the lowest value of Rflop=1.79313e+14
# Compute time:             624.8828 Nh
# Ingest visibility size:   4025 GB
# Averaged visibility size: 153 GB
# Output size:              6353 GB
# Fiducial frequency:       1426.70402381641 MHz
# Beam size:                1.80592915066979"
# Pixel size:               0.601976383556598"
#
# === SC-018 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=214.701, Rflop=3.24894e+13
# Evaluating Nfacet=2 -> DeltaW_stack=267.747, Rflop=4.6782e+13
# Evaluating Nfacet=3 -> DeltaW_stack=315.089, Rflop=6.43734e+13
# Nfacet=1, DeltaW_stack=214.701  yielded the lowest value of Rflop=3.24894e+13
# Compute time:             113.2216 Nh
# Ingest visibility size:   1013 GB
# Averaged visibility size: 51 GB
# Output size:              706 GB
# Fiducial frequency:       1426.70402381641 MHz
# Beam size:                5.41778745200938"
# Pixel size:               1.80592915066979"
#
# === SC-018 SIMG 3 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=79.6164, Rflop=1.57802e+13
# Evaluating Nfacet=2 -> DeltaW_stack=97.1389, Rflop=2.56619e+13
# Evaluating Nfacet=3 -> DeltaW_stack=112.625, Rflop=4.15312e+13
# Nfacet=1, DeltaW_stack=79.6164  yielded the lowest value of Rflop=1.57802e+13
# Compute time:             54.99199 Nh
# Ingest visibility size:   215 GB
# Averaged visibility size: 17 GB
# Output size:              79 GB
# Fiducial frequency:       1426.70402381641 MHz
# Beam size:                16.2533623560281"
# Pixel size:               5.41778745200938"
#
# === SC-019 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=6629.65, Rflop=3.83518e+13
# Evaluating Nfacet=2 -> DeltaW_stack=8816.37, Rflop=4.86276e+13
# Evaluating Nfacet=3 -> DeltaW_stack=10538.6, Rflop=5.85218e+13
# Nfacet=1, DeltaW_stack=6629.65  yielded the lowest value of Rflop=3.83518e+13
# Compute time:             133.6511 Nh
# Ingest visibility size:   4441 GB
# Averaged visibility size: 398 GB
# Output size:              0 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-019 CIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=2409.8, Rflop=4.25087e+13
# Evaluating Nfacet=2 -> DeltaW_stack=3128.6, Rflop=7.02053e+13
# Evaluating Nfacet=3 -> DeltaW_stack=3782.99, Rflop=1.07415e+14
# Nfacet=1, DeltaW_stack=2409.8  yielded the lowest value of Rflop=4.25087e+13
# Compute time:             148.1373 Nh
# Ingest visibility size:   4441 GB
# Averaged visibility size: 398 GB
# Output size:              57 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.215483337490622"
# Pixel size:               0.0718277791635407"
#
# === SC-019 CIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=1305.79, Rflop=4.77688e+12
# Evaluating Nfacet=2 -> DeltaW_stack=1574.93, Rflop=1.02156e+13
# Evaluating Nfacet=3 -> DeltaW_stack=1821.86, Rflop=1.89672e+13
# Nfacet=1, DeltaW_stack=1305.79  yielded the lowest value of Rflop=4.77688e+12
# Compute time:             16.64682 Nh
# Ingest visibility size:   1118 GB
# Averaged visibility size: 45 GB
# Output size:              7 GB
# Fiducial frequency:       11956.9634292493 MHz
# Beam size:                0.646450012471866"
# Pixel size:               0.215483337490622"
#
# === SC-019 SIMG 1 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=31513.7, Rflop=5.29583e+14
# Evaluating Nfacet=2 -> DeltaW_stack=31513.7, Rflop=7.42908e+14
# Evaluating Nfacet=3 -> DeltaW_stack=31513.7, Rflop=7.69374e+14
# Nfacet=1, DeltaW_stack=31513.7  yielded the lowest value of Rflop=5.29583e+14
# Compute time:             1845.53 Nh
# Ingest visibility size:   4007 GB
# Averaged visibility size: 304 GB
# Output size:              13 GB
# Fiducial frequency:       12001.6798823835 MHz
# Beam size:                0.214680479002765"
# Pixel size:               0.0715601596675884"
#
# === SC-019 SIMG 2 ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=10504.6, Rflop=6.22868e+13
# Evaluating Nfacet=2 -> DeltaW_stack=10504.6, Rflop=9.87837e+13
# Evaluating Nfacet=3 -> DeltaW_stack=10504.6, Rflop=1.26626e+14
# Nfacet=1, DeltaW_stack=10504.6  yielded the lowest value of Rflop=6.22868e+13
# Compute time:             217.0615 Nh
# Ingest visibility size:   1008 GB
# Averaged visibility size: 102 GB
# Output size:              2 GB
# Fiducial frequency:       12001.6798823835 MHz
# Beam size:                0.644041437008296"
# Pixel size:               0.214680479002765"
#
# === SC-020 ICAL ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=31.5634, Rflop=2.08696e+14
# Evaluating Nfacet=2 -> DeltaW_stack=43.7951, Rflop=2.28729e+14
# Evaluating Nfacet=3 -> DeltaW_stack=55.7157, Rflop=2.1826e+14
# Evaluating Nfacet=4 -> DeltaW_stack=65.2788, Rflop=2.34302e+14
# Evaluating Nfacet=5 -> DeltaW_stack=73.0326, Rflop=2.67163e+14
# Nfacet=1, DeltaW_stack=31.5634  yielded the lowest value of Rflop=2.08696e+14
# Compute time:             45.45505 Nh
# Ingest visibility size:   288 GB
# Averaged visibility size: 48 GB
# Output size:              0 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-020 CIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=14.5009, Rflop=1.5529e+14
# Evaluating Nfacet=2 -> DeltaW_stack=19.2055, Rflop=2.10899e+14
# Evaluating Nfacet=3 -> DeltaW_stack=23.4639, Rflop=2.65024e+14
# Nfacet=1, DeltaW_stack=14.5009  yielded the lowest value of Rflop=1.5529e+14
# Compute time:             33.82291 Nh
# Ingest visibility size:   288 GB
# Averaged visibility size: 48 GB
# Output size:              87 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"
#
# === SC-020 SIMG  ===
# Baseline coalescing on
# Evaluating Nfacet=1 -> DeltaW_stack=21.2541, Rflop=1.53483e+14
# Evaluating Nfacet=2 -> DeltaW_stack=29.3069, Rflop=1.78388e+14
# Evaluating Nfacet=3 -> DeltaW_stack=36.8697, Rflop=1.89597e+14
# Nfacet=1, DeltaW_stack=21.2541  yielded the lowest value of Rflop=1.53483e+14
# Compute time:             33.42935 Nh
# Ingest visibility size:   288 GB
# Averaged visibility size: 48 GB
# Output size:              216 GB
# Fiducial frequency:       602.281412480935 MHz
# Beam size:                4.27794438379668"
# Pixel size:               1.42598146126556"

# %%
with open(pipeline_config_output_path, "w") as f:
    json.dump(pipelines, f, indent=4)
with open(scheduling_block_types_config_output_path, "w") as f:
    json.dump(scheduling_block_types, f, indent=4)
